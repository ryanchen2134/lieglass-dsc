# %% [markdown]
# # LieGlass — Complete Plot Generation Notebook
# Run each cell independently. All plots save to `output/plots/`.
#
# | Plot | Description | Needs |
# |------|-------------|-------|
# | B | ROC Curve | `model_predictions.csv` |
# | C | Confidence Density | `model_predictions.csv` |
# | D | Per-Fold Metrics | `metrics.json` |
# | E | Human vs LieGlass | hardcoded |
# | H | Logit Health Scatter | `metrics.json` |
# | I | Ablation Chart | placeholders |
# | L | KPI Strip | hardcoded |
# | M | Lying Spectrum | hardcoded |
# | N | Detection Timeline | hardcoded |
# | O | Dataset Composition | hardcoded |
# | P | Model Pipeline | hardcoded |
# | Q | Cross-Fusion Benefit | hardcoded |
# | R | LLM Pipeline | hardcoded |
# | S | Observe vs Act | hardcoded |
# | T | LLM Output Mockup | hardcoded |
# | U | Reverse Engineering | hardcoded |
# | V | Why Glasses | hardcoded |
# | W | Lie Score Trajectory | hardcoded |
# | X | What Model Sees | hardcoded |
# | Y | Product Roadmap | hardcoded |

# %%
import os
os.chdir(os.path.dirname(os.path.abspath('__file__')))
print('Working directory:', os.getcwd())

# %% [markdown]
# ## Results / Model Performance

# %%
# B — ROC Curve (needs model_predictions.csv)
# %run plot_B_roc_curve.py

# %%
# C — Confidence Density (needs model_predictions.csv)
# %run plot_C_density.py

# %%
# D — Per-Fold Metrics Bar Chart
# %run plot_D_per_fold_metrics.py

# %%
# E — Human vs LieGlass
# %run plot_E_human_vs_model.py

# %%
# H — Logit Health Scatter
# %run plot_H_logit_health.py

# %%
# I — Ablation (update values in script when real data available)
# %run plot_I_ablation.py

# %%
# L — KPI Summary Strip
# %run plot_L_kpi_strip.py

# %% [markdown]
# ## Introduction / Problem Framing

# %%
# M — Lying Spectrum
# %run plot_M_lying_spectrum.py

# %%
# N — Detection Technology Timeline
# %run plot_N_detection_timeline.py

# %% [markdown]
# ## Dataset

# %%
# O — Dataset Composition
# %run plot_O_dataset_composition.py

# %% [markdown]
# ## Model Architecture

# %%
# P — Model Architecture Pipeline
# %run plot_P_model_pipeline.py

# %%
# Q — Cross-Fusion Temporal Benefit
# %run plot_Q_cross_fusion_benefit.py

# %%
# X — What the Model Sees
# %run plot_X_what_model_sees.py

# %% [markdown]
# ## LLM Section

# %%
# R — Three-Layer LLM Pipeline
# %run plot_R_llm_pipeline.py

# %%
# S — Observe vs Act
# %run plot_S_observe_vs_act.py

# %%
# T — LLM Output Mockup
# %run plot_T_llm_output_mockup.py

# %% [markdown]
# ## Glasses Section

# %%
# U — Reverse Engineering Journey
# %run plot_U_reverse_engineering.py

# %%
# V — Why Glasses
# %run plot_V_why_glasses.py

# %%
# W — Live Lie Score Trajectory
# %run plot_W_lie_score_trajectory.py

# %% [markdown]
# ## Evaluation / Conclusion

# %%
# Y — Product Roadmap
# %run plot_Y_product_roadmap.py

# %%
# List all saved plots
import os
ROOT = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
plots = sorted(f for f in os.listdir(os.path.join(ROOT, 'output', 'plots')) if f.endswith('.png'))
print(f'Total plots saved: {len(plots)}')
for p in plots:
    print(f'  output/plots/{p}')
